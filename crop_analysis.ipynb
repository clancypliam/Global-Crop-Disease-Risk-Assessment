# %%
# !pip install pandas
import pandas as pd

# Load your crop data spreadsheet
df = pd.read_csv("datasets/global_crop_disease_risk_prediction_2026_2100.csv")

# Print the top 5 lines of data to your screen
df.head()
# Out:
# ...
#     country      region continent   climate_zone  year  season crop_type  \
# 0  Pakistan  South Asia      Asia  Hot Semi-Arid  2026  Spring     Wheat
# 1  Pakistan  South Asia      Asia  Hot Semi-Arid  2026  Summer     Wheat
# 2  Pakistan  South Asia      Asia  Hot Semi-Arid  2026  Autumn     Wheat
# 3  Pakistan  South Asia      Asia  Hot Semi-Arid  2026  Winter     Wheat
# 4  Pakistan  South Asia      Asia  Hot Semi-Arid  2026  Spring      Rice
#
#   crop_group growth_stage  irrigation_type  ...  disease_probability  \
# 0     Cereal     Seedling   Drip Irrigated  ...               0.5151
# 1     Cereal   Vegetative  Canal Irrigated  ...               0.4947
# 2     Cereal     Maturity          Rainfed  ...               0.5014
# 3     Cereal     Seedling          Rainfed  ...               0.7049
# 4     Cereal   Vegetative  Canal Irrigated  ...               0.5224
#
#    disease_severity  outbreak_probability_next_30_days  \
# ...
